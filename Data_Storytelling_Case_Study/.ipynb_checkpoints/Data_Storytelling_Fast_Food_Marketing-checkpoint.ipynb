# %% [markdown]
# # Data_Storytelling_Case_Study: Fast Food Marketing<a id='2_Data_wrangling'></a>

# %% [markdown]
# ## 0. Table of Contents<a id='2.1_Contents'></a>
# * Fast Food Marketing Notebook
#   * 0. Table of Contents
#   * 1. Introduction
#   * 2. Imports
#   * 3. Load Fast Food Marketing Data
#   * 4. Explore The Data
#     * 4.1 Assess Missing Values By Column
#     * 4.2 Assessing Marketing Data Based on Features
#     * 4.3 Correlation Based on Target (SalesInThousands)
#       * 4.3.1 Assessing Max Values
#       *  4.3.2 Heatmap & Correlations (SalesInThousands)
#   * 5. Save data
#   * 6. Summary

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Fast Food Company dataset retreived from: https://www.kaggle.com/datasets/chebotinaa/fast-food-marketing-campaign-ab-test/
# details different columns as mentioned in the summary within the link of MarketID, MarketSize (size of the market given sales), LocationID, AgeofStore in years, Promotion (details which promotion was lauched for the store), week (which week of the 4 weeks of a month the promotion was tested on), and SalesinThousands (amount of sales given LocationID, Promotion, and week).
#
# The goal of this notebook is to glean any important insights or trends given the dataset to understand the marketing campaign data in order to assist in company decion making. The audience for the notebook will be employees within the Fast Food Company and those invovled with overall decision making.

# %% [markdown]
# ## 2. Imports<a id='2.3_Imports'></a>

# %% [markdown]
# Importing all appropriate packages in order to verify/clean the databset provided.

# %%
#Import pandas, matplotlib.pyplot, seaborn, and ydata Profile report
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np
import os
from ydata_profiling import ProfileReport

# %% [markdown]
# ## 3. Load Fast Food Marketing Data

# %%
# Load the CSV Fast Food Marketing Data
food_df = pd.read_csv('C:/Users/tpooz/OneDrive/Desktop/Data_Science_BootCamp_2023/SpringBoard_Github/Springboard/Data_Storytelling_Case_Study/WA_Marketing_Campaign.csv')

# %% [markdown]
# Auditing the dataset with .info() and .head() displaying the first few records.

# %%
#info method on bank_df to see a summary of the data
food_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MarketID          548 non-null    int64
#  1   MarketSize        548 non-null    object
#  2   LocationID        548 non-null    int64
#  3   AgeOfStore        548 non-null    int64
#  4   Promotion         548 non-null    int64
#  5   week              548 non-null    int64
#  6   SalesInThousands  548 non-null    float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 30.1+ KB

# %%
#head method on bank_df to print the first several rows of the data
food_df.head()
# Out:
#    MarketID MarketSize  LocationID  AgeOfStore  Promotion  week  \
# 0         1     Medium           1           4          3     1
# 1         1     Medium           1           4          3     2
# 2         1     Medium           1           4          3     3
# 3         1     Medium           1           4          3     4
# 4         1     Medium           2           5          2     1
#
#    SalesInThousands
# 0             33.73
# 1             35.67
# 2             29.03
# 3             39.25
# 4             27.81

# %% [markdown]
# ## 4. Explore The Data

# %% [markdown]
# ### 4.1 Assess Missing Values By Column

# %% [markdown]
# Count the number of missing values in each column.

# %%
food_df.isna().sum()
# Out:
# MarketID            0
# MarketSize          0
# LocationID          0
# AgeOfStore          0
# Promotion           0
# week                0
# SalesInThousands    0
# dtype: int64

# %% [markdown]
# The dataset intially seems 'tidy' where every feature has filled in observations, however a further analysis is needed to see if any values have been imputed with 0 or 'missing', etc.

# %%
#Assessing columns as well based on .describe() method
food_df.describe().T
# Out:
#                   count        mean         std    min      25%    50%  \
# MarketID          548.0    5.715328    2.877001   1.00    3.000    6.0
# LocationID        548.0  479.656934  287.973679   1.00  216.000  504.0
# AgeOfStore        548.0    8.503650    6.638345   1.00    4.000    7.0
# Promotion         548.0    2.029197    0.810729   1.00    1.000    2.0
# week              548.0    2.500000    1.119055   1.00    1.750    2.5
# SalesInThousands  548.0   53.466204   16.755216  17.34   42.545   50.2
#
#                        75%     max
# MarketID            8.0000   10.00
# LocationID        708.0000  920.00
# AgeOfStore         12.0000   28.00
# Promotion           3.0000    3.00
# week                3.2500    4.00
# SalesInThousands   60.4775   99.65

# %%
#Assessing number of categorical columns in the dataset.
food_df['MarketSize'].value_counts()
# Out:
# Medium    320
# Large     168
# Small      60
# Name: MarketSize, dtype: int64

# %%
#Determing all the unique values found in the categorical column.
food_df['MarketSize'].unique()
# Out:
# array(['Medium', 'Small', 'Large'], dtype=object)

# %% [markdown]
# The categories of MarketID, LocationID, Promotion, and week seem to all have indepedent single value distribution for each observation or namely that each of these categories seem to just be labels for each observation. Therefore, in order to prevent skew of results, these columns will be converted into unique categorical columns instead of its current 'numeric' distribution. The columns 'Promotion' and 'week' will also be assessed for unique to assess any 0 or 'missing' values.

# %%
#Method to convert int64 to object or str found on https://stackoverflow.com/questions/17950374/converting-a-column-within-pandas-dataframe-from-int-to-string
food_df['MarketID'] = food_df['MarketID'].apply(str)
food_df['LocationID'] = food_df['LocationID'].apply(str)
food_df['Promotion'] = food_df['Promotion'].apply(str)
food_df['week'] = food_df['week'].apply(str)
food_df.dtypes
# Out:
# MarketID             object
# MarketSize           object
# LocationID           object
# AgeOfStore            int64
# Promotion            object
# week                 object
# SalesInThousands    float64
# dtype: object

# %%
food_df['Promotion'].value_counts()
# Out:
# 3    188
# 2    188
# 1    172
# Name: Promotion, dtype: int64

# %%
food_df['week'].value_counts()
# Out:
# 1    137
# 2    137
# 3    137
# 4    137
# Name: week, dtype: int64

# %% [markdown]
# It seems looking at the describe for the numerical feature and slicing to retrieve the categorical feature, that for the numerical values the minumum value is 1 for most of the columns, meaning there is no imputed 0 column and for the categorical column, it seems there is no 'missing' or other form of imputation for any missing data. Therefore, the dataset seems tidy.

# %%
#Created a ydata profile report to provide further analysis breakdown of dataset.
profile = ProfileReport(food_df, title="Profiling Report")
profile.to_file('Fast_Food_Dataset_Profile_Report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Based on the ydata profile report, it seems the dataset however has some highly correlated features most notably being that SalesInThousands and MarketSize. This might pose an issue in future work as per developing predicability model for SalesInThousands and therefore potential to be dropped as a column for training the predictive model.

# %% [markdown]
# ### 4.2 Assessing Marketing Data Based on Features

# %%
#Plot distribution of MarketSize
#Code to reorient order of categorical column found on https://stackoverflow.com/questions/44067951/sorting-categorical-labels-in-seaborn-chart
sns.histplot(data=food_df.sort_values(by='MarketSize', ascending=False), x='MarketSize')
plt.show()

# %%
sns.histplot(data=food_df , x='AgeOfStore')
plt.show()

# %% [markdown]
# Before performing further steps in EDA, taking a quick look at the max values of sales for the dataset.

# %%
#Retreiving max value for dataframe based on SalesInThousands and assessing top 5 rows as well.
food_df[food_df['SalesInThousands'] == max(food_df['SalesInThousands'])]
# Out:
#     MarketID MarketSize LocationID  AgeOfStore Promotion week  \
# 144        3      Large        218           2         1    1
#
#      SalesInThousands
# 144             99.65

# %%
food_df.sort_values(by='SalesInThousands', ascending=False).head()
# Out:
#     MarketID MarketSize LocationID  AgeOfStore Promotion week  \
# 144        3      Large        218           2         1    1
# 154        3      Large        220           3         1    3
# 111        3      Large        209           1         1    4
# 104        3      Large        208           1         3    1
# 109        3      Large        209           1         1    2
#
#      SalesInThousands
# 144             99.65
# 154             99.12
# 111             97.61
# 104             96.48
# 109             96.01

# %% [markdown]
# The max values reveals that week 1 and promotion item 1 gave the company the highest number in its sales. And taking a look at the top 5 sales data, it seems there is some variation in terms of highest sales for week, but it seems just at a quick glance that Promotion item 1 has been providing the highest sales for the company when it was distributed to the relatively younger in years stores within the large market size.

# %% [markdown]
# The below steps will allow us to retreive further information and insight regarding the dataset for the current Marketing Data.

# %%
sns.histplot(data=food_df , x='SalesInThousands', hue='MarketSize', hue_order=['Small', 'Medium', 'Large'])
plt.show()

# %%
line_market = sns.lineplot(data=food_df , x='week', y='SalesInThousands', hue='MarketSize', hue_order=['Small', 'Medium', 'Large'])
sns.move_legend(line_market, 'upper right')
plt.show()

# %%
line_promotion = sns.lineplot(data=food_df , x='week', y='SalesInThousands', hue ='Promotion', estimator='mean', hue_order = ['1','2','3'])
sns.move_legend(line_promotion, 'upper left')
plt.show()

# %%
#Barplot formatting found on sns.barplot documentation: http://seaborn.pydata.org/generated/seaborn.barplot.html
ax = sns.barplot(food_df, x="week", y="SalesInThousands", hue='Promotion', hue_order=['1','2','3'], estimator='mean', errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10)
ax.bar_label(ax.containers[1], fontsize=10)
ax.bar_label(ax.containers[2], fontsize=10)
sns.move_legend(ax, 'lower right')
plt.show()

# %% [markdown]
# Looking at the above resulting plots, some trends for the dataset seem to be that most of the data is coming from a Medium sized market thereby meaning the dataset is imbalanced as per number of observations from each market size. It also seems that the company seems to have a wide range in terms of different store age, however age of the store seems to average at around 8.5 years. This means the company as a whole has a larger amount of stores on the newer side in terms of their respective market than being more established. It also appears that the highest sales came from Promotion item 1 when it was distributed to the younger in years stores.
#
# Looking at the SalesinThounsands versus different featuers within the dataset, some other mentions are that the histogram of sales with market sizes shows that the large market size has the highest number as per sales for the fast food product and on average the small market size seems to be second larger to the medium. This means that though the medium size is the largest as per volume or count, not often does this market size seem to be the highest gross income for the company. This discrepency between market sizes can also be seen with the lineplot comparing weeks of promotional item distribution and sales looking at the various market sizes.
#
# However, the lineplot comparing weeks and sales among the different promotional items distributed within each of the stores gives a better representation of the story for the fast food company's marketing campaign. It seems that on the whole, Promotion 1 item had the largest amount of mean sales for the company where as Promotion 2 item had the least number in mean sales and in fact by week 4 the mean sales were even on the decline. It seems that Promotion 3 had an overall mixed response where there was an increase from week 1 to 2 and then decrease to week 3 with an increase again to week 4. Looking at some other trends from the lineplot, week 3 had the highest mean sales for Promotion item 1 and 2, and week 2 had the highest promotion item mean sales for week 3. The actual numbers for the mean of sales can be seen and compared from the barplot of the associated information.

# %% [markdown]
# ### 4.3 Correlation Based on Target (SalesInThousands)

# %% [markdown]
# Creating a correlation object and heatmap to display correlation of features with target SalesInThousands.

# %%
#Converting current dataframe to add numeric values for categorical columns and dropping MarketID and LocationID since 
#these features are just independent labels for each of the observations.
food_df_dropped = food_df.drop(['MarketID', 'LocationID'], axis=1)
food_df_dummy_dropped = pd.get_dummies(food_df_dropped)

# %%
sns.heatmap(food_df_dummy_dropped.corr())
plt.show()

# %%
#Retrieved just the SalesInThousands column from the correlation dataframe created and sorted based on correlation values
corr_df = food_df_dummy_dropped.corr()
corr_df['SalesInThousands'].sort_values(ascending=False)
# Out:
# SalesInThousands     1.000000
# MarketSize_Large     0.661359
# Promotion_1          0.187181
# MarketSize_Small     0.082595
# Promotion_3          0.081947
# week_1               0.011188
# week_3               0.000290
# week_2              -0.002747
# week_4              -0.008731
# AgeOfStore          -0.028533
# Promotion_2         -0.264920
# MarketSize_Medium   -0.670968
# Name: SalesInThousands, dtype: float64

# %% [markdown]
# From the correlation values listed above, it seems that MarketSize_Large is as seen with the Alert from ydata profiling, highly correlated with the SalesInThousands so there might be intercollineraity between the features, same with MarketSize_Medium. However, some noteable trends are seen from the dataset. It seems that Promotion_1 item had a stronger positive correlation with the sales column than the other promotional items with Promotion_3 being slightly positive and Promotion_2 being actually more negative. In terms of weeks when the different promotion items were distributed, week_1 and week_3 had a positive correlation with sales and week_2 and week_4 were negative in correlation to sales. Thoguh these values of correlation are somewhat slight, so it is not conclusive if each week of distribution had a significant impact to overall sales. This seems to indicate given just this dataset that younger stores seemed to be generating more income than its more established counterparts. Therefore, it might be intersting retrieve this dataset again in another 5 years to see if the same new stores now are still able to meet sales goals.

# %% [markdown]
# ## 5. Save data

# %% [markdown]
# In order to avoid the dummy variable trap, the MarketSize_Medium variable since it is the most common, Promotion_1 and Week_1 since it was the features with highest positive correlation, will be dropped in terms for any potential future model development.

# %%
food_df_dummy_dropped = food_df_dummy_dropped.drop(['MarketSize_Medium'], axis=1)
food_df_dummy_dropped = food_df_dummy_dropped.drop(['Promotion_1'], axis=1)
food_df_dummy_dropped = food_df_dummy_dropped.drop(['week_1'], axis=1)

# %%
food_df_dummy_dropped.shape
# Out:
# (548, 9)

# %%
# save the data to a new csv file
datapath = 'C:/Users/tpooz/OneDrive/Desktop/Data_Science_BootCamp_2023/SpringBoard_Github/Springboard/Data_Storytelling_Case_Study/Dataset/food_df_dummy.csv'
food_df_dummy_dropped.to_csv(datapath)

# %% [markdown]
# ## 6. Summary

# %% [markdown]
# Few different insights were gleaned in terms of the dataset for the marketing data for the Fast Food company. It seems that according to the max vales as per SalesInThousands was found when the company intiated promotion 1 on week 1 of the large market size group. And regardless it seemed that promotion 1 had the highest value in terms of SalesInThousands. It also seems that correlation has a somewhat negative correlation though to the SalesInThousands column which will need to be further investigated. The company also seems to on a whole have stores that are relatively younger in terms of establishment and it seems the max sales values were being retrieved from this relatively newer lines of stores. A potential factor could be the 'newness' of these stores given the area so this could be a potential factor affecting the skew. This dataset will need to be further assessed and retreieved again potentially in another five years to see if the younger stores are still able to meet sales goals.
#
# From the correlation values listed above, it seems that MarketSize_Large is as seen with the Alert from ydata profiling, highly correlated with the SalesInThousands so there might be intercollineraity between the features. However, some more trends are seen from the dataset. It seems that Promotion_1 item had a positive correlation with the sales column and again it can be seen that the small marketsize had also a positive correlation to the sales for the company. It also seems that Promotion 3 also had a slight positive correlation to sales. In terms of negative correlations, week 2 and week 4 seemed to negatively correlated and even AgeofStore seemed to be negatively correlated. In terms of AgeofStore, this might indicate that younger stores seemed to be performing better than its more established counterparts. Therefore, it might be intersting to perform the marketing campaign in another 5 years and see if the newer stores are still able to meet sales goals. And it seems as seeing the correlation that Promotion item 2 had a negative correlation to sales. Therefore it might be in the best interest for the company to distribute more of item 1 and 3 to their stores than item 2.
#
# Overall the dataset is tidy, and future work will need to be implemented in order to see if a potentially a Regression predictive model can be created to determine the Target SalesInThousands column given the company promotion and week being distributed.
